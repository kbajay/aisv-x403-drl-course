# %%
# !pip install gymnasium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# !pip install gymnasium[toy_text]

# %%
import gymnasium as gym

# %%
env = gym.make("Taxi-v3", render_mode='rgb_array')

# %%
env
# Out:
# <TimeLimit<OrderEnforcing<PassiveEnvChecker<TaxiEnv<Taxi-v3>>>>>

# %%
state = env.reset()

# %%
print(state)
# Out:
# (328, {'prob': 1.0, 'action_mask': array([1, 1, 1, 0, 0, 0], dtype=int8)})

# %%
env.render()
# Out:
# array([[[110, 109, 106],
#         [110, 109, 106],
#         [124, 122, 122],
#         ...,
#         [108, 111, 109],
#         [108, 111, 109],
#         [118, 119, 119]],
#
#        [[110, 109, 106],
#         [110, 109, 106],
#         [124, 122, 122],
#         ...,
#         [108, 111, 109],
#         [108, 111, 109],
#         [118, 119, 119]],
#
#        [[114, 116, 115],
#         [114, 116, 115],
#         [126, 127, 126],
#         ...,
#         [112, 113, 111],
#         [112, 113, 111],
#         [118, 117, 115]],
#
#        ...,
#
#        [[116, 115, 116],
#         [116, 115, 116],
#         [106, 107, 108],
#         ...,
#         [113, 115, 114],
#         [113, 115, 114],
#         [117, 114, 117]],
#
#        [[116, 115, 116],
#         [116, 115, 116],
#         [106, 107, 108],
#         ...,
#         [113, 115, 114],
#         [113, 115, 114],
#         [117, 114, 117]],
#
#        [[115, 112, 112],
#         [115, 112, 112],
#         [119, 119, 117],
# ...

# %%
env.reset()
# Out:
# (82, {'prob': 1.0, 'action_mask': array([1, 0, 0, 1, 0, 0], dtype=int8)})

# %%
env.render()
# Out:
# array([[[110, 109, 106],
#         [110, 109, 106],
#         [124, 122, 122],
#         ...,
#         [108, 111, 109],
#         [108, 111, 109],
#         [118, 119, 119]],
#
#        [[110, 109, 106],
#         [110, 109, 106],
#         [124, 122, 122],
#         ...,
#         [108, 111, 109],
#         [108, 111, 109],
#         [118, 119, 119]],
#
#        [[114, 116, 115],
#         [114, 116, 115],
#         [126, 127, 126],
#         ...,
#         [112, 113, 111],
#         [112, 113, 111],
#         [118, 117, 115]],
#
#        ...,
#
#        [[116, 115, 116],
#         [116, 115, 116],
#         [106, 107, 108],
#         ...,
#         [113, 115, 114],
#         [113, 115, 114],
#         [117, 114, 117]],
#
#        [[116, 115, 116],
#         [116, 115, 116],
#         [106, 107, 108],
#         ...,
#         [113, 115, 114],
#         [113, 115, 114],
#         [117, 114, 117]],
#
#        [[115, 112, 112],
#         [115, 112, 112],
#         [119, 119, 117],
# ...

# %%
# !pip install gym-simplegrid

# %%
import gym_simplegrid

# %%
env = gym.make('SimpleGrid-8x8-v0', render_mode='rgb_array')

# %%
env.reset()
# Out:
# (58, {'agent_xy': (7, 2)})

# %%
env.render()
# Out:
# array([[[170, 170, 170],
#         [170, 170, 170],
#         [170, 170, 170],
#         ...,
#         [170, 170, 170],
#         [170, 170, 170],
#         [170, 170, 170]],
#
#        [[170, 170, 170],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[170, 170, 170],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[170, 170, 170],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[170, 170, 170],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[170, 170, 170],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
env=gym.make('CartPole-v1', render_mode='rgb_array')

# %%
env.reset()
# Out:
# (array([-0.02824342, -0.02386861,  0.02377056, -0.01853509], dtype=float32),
#  {})

# %%
env.render()
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
#import matplotlib.pyplot as plt
#%matplotlib inline

# %%
#plt.imshow(env.render(mode='rgb_array'))

# %%
#plt.imshow(env.render(mode='rgb_array'))

# %%
env.spec
# Out:
# EnvSpec(id='CartPole-v1', entry_point='gymnasium.envs.classic_control.cartpole:CartPoleEnv', reward_threshold=475.0, nondeterministic=False, max_episode_steps=500, order_enforce=True, autoreset=False, disable_env_checker=False, apply_api_compatibility=False, kwargs={'render_mode': 'rgb_array'}, namespace=None, name='CartPole', version=1, additional_wrappers=(), vector_entry_point='gymnasium.envs.classic_control.cartpole:CartPoleVectorEnv')

# %%
env.observation_space.shape
# Out:
# (4,)

# %%
env.action_space
# Out:
# Discrete(2)

# %%
print(env.action_space)
print(env.observation_space)
# Out:
# Discrete(2)
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
action = 1
env.step(action)
env.step(action)
env.step(action)
env.step(action)
# Out:
# (array([-0.00677778,  0.7556065 , -0.01196959, -1.1669441 ], dtype=float32),
#  1.0,
#  False,
#  False,
#  {})

# %%
#plt.imshow(env.render(mode='rgb_array'))
env.render()
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
action = 1
env.step(action)
env.step(action)
env.step(action)
env.step(action)
# Out:
# (array([ 0.07712451,  1.5381898 , -0.14149068, -2.400732  ], dtype=float32),
#  1.0,
#  False,
#  False,
#  {})

# %%
#plt.imshow(env.render(mode='rgb_array'))
env.render()
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
env=gym.make("MountainCar-v0", render_mode='rgb_array')

# %%
env.reset()
# Out:
# (array([-0.55110496,  0.        ], dtype=float32), {})

# %%
#plt.imshow(env.render(mode='rgb_array'))
env.render()
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
action = 2

# %%
for _ in range(10000):
  env.step(action)

# %%
#plt.imshow(env.render(mode='rgb_array'))
env.render()
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
# !pip install gymnasium[mujoco]

# %%
env=gym.make("HalfCheetah-v4", render_mode='rgb_array')
# Out:
# ---------------------------------------------------------------------------
# DependencyNotInstalled                    Traceback (most recent call last)
# <ipython-input-74-6e13bd96fdbc> in <cell line: 1>()
# ----> 1 env=gym.make("HalfCheetah-v4", render_mode='rgb_array')
#       2
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/envs/registration.py in make(id, max_episode_steps, autoreset, apply_api_compatibility, disable_env_checker, **kwargs)
#     800
#     801     try:
# --> 802         env = env_creator(**env_spec_kwargs)
#     803     except TypeError as e:
#     804         if (
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/envs/mujoco/half_cheetah_v4.py in __init__(self, forward_reward_weight, ctrl_cost_weight, reset_noise_scale, exclude_current_positions_from_observation, **kwargs)
#     180             )
#     181
# --> 182         MujocoEnv.__init__(
#     183             self,
#     184             "half_cheetah.xml",
#
# ...

# %%
# !apt-get install -y \
    libgl1-mesa-dev \
    libgl1-mesa-glx \
    libglew-dev \
    libosmesa6-dev \
    software-properties-common

# !apt-get install -y patchelf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgl1-mesa-dev is already the newest version (20.0.8-0ubuntu1~18.04.1).
# libgl1-mesa-dev set to manually installed.
# software-properties-common is already the newest version (0.96.24.32.18).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# Suggested packages:
#   glew-utils
# The following NEW packages will be installed:
#   libgl1-mesa-glx libglew-dev libglew2.0 libosmesa6 libosmesa6-dev
# 0 upgraded, 5 newly installed, 0 to remove and 4 not upgraded.
# Need to get 2,916 kB of archives.
# After this operation, 12.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgl1-mesa-glx amd64 20.0.8-0ubuntu1~18.04.1 [5,532 B]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libglew2.0 amd64 2.0.0-5 [140 kB]
# ...

# %%
# !pip install mujoco-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.4 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 207 kB 58.0 MB/s
# ...

# %%
import mujoco_py
# Out:
# You appear to be missing MuJoCo.  We expected to find the file here: /root/.mujoco/mujoco210
#
# This package only provides python bindings, the library must be installed separately.
#
# Please follow the instructions on the README to install MuJoCo
#
#     https://github.com/openai/mujoco-py#install-mujoco
#
# Which can be downloaded from the website
#
#     https://www.roboti.us/index.html
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-40-85c6ae7fd0aa> in <module>
# ----> 1 import mujoco_py
#
# /usr/local/lib/python3.7/dist-packages/mujoco_py/__init__.py in <module>
#       1 #!/usr/bin/env python
# ----> 2 from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#       3 from mujoco_py.generated import const
#       4 from mujoco_py.mjrenderpool import MjRenderPool
# ...

# %%
env=gym.make("FrozenLake-v1")

# %%
env.reset()
# Out:
# 0

# %%
plt.imshow(env.render())
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/core.py:50: DeprecationWarning: WARN: You are calling render method, but you didn't specified the argument render_mode at environment initialization. To maintain backward compatibility, the environment will render in human mode.
# If you want to render in human mode, initialize the environment in this way: gym.make('EnvName', render_mode='human') and don't call the render method.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   "You are calling render method, "
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-45-152c396fb126> in <module>
# ----> 1 plt.imshow(env.render())
#
# /usr/local/lib/python3.7/dist-packages/gym/core.py in render(self, *args, **kwargs)
#      56             )
#      57
# ---> 58         return render_func(self, *args, **kwargs)
#      59
#      60     return render
#
# ...

# %%
import numpy as np
import random
from IPython.display import clear_output
from collections import deque
import progressbar

# %%
# !pip install gym[toy_text]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 18.3 MB 4.4 MB/s
# ...

# %%
import gym
env = gym.make('Taxi-v3')
env.reset()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/core.py:318: DeprecationWarning: WARN: Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing wrapper in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/step_api_compatibility.py:40: DeprecationWarning: WARN: Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future.
#   "Initializing environment in old step API which returns one bool instead of two. It is recommended to set `new_step_api=True` to use new step API. This will be the default behaviour in future."
# 214

# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# *   Action space: Discrete(6)
# *   State space: Discreate(500)

# %%
plt.imshow(env.render(mode='rgb_array'))
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/core.py:44: DeprecationWarning: WARN: The argument mode in render method is deprecated; use render_mode during environment initialization instead.
# See here for more information: https://www.gymlibrary.ml/content/api/
#   "The argument mode in render method is deprecated; "

# %% [markdown]
# Actions<br>0: move south<br>
# 1: move north<br>
# 2: move east<br>
# 3: move west<br>
# 4: pickup passenger<br>
# 5: drop off passenger<br>

# %% [markdown]
# State:<br>
# 5x5: taxi positions<br>
# passenger location: 5:  Red, Green, Blue, Yellow, In taxi<br>
# Four desinations<br>
#
# Total states: 5x5x5x4 = 500

# %% [markdown]
# Blue means pick up location
# <br>Pink is drop
